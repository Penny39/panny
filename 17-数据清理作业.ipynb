# %%
import mytools

# %%
数据表=mytools.读取SPSS数据文件(R"data\国家认同数据清理后.sav")

# %%
#空白值的处理
数据表.dropna(thresh=4, inplace=True)

# %%
#异常值

# %%
数据表.drop_duplicates(subset=['问卷编号'])
# Out:
#       问卷编号  调查员    民族 政治面貌  年级 您觉得自己是个典型的中国人吗 与世界其他国家的人相比中国人有自己的特点吗  \
# 0    681.0   刘利    汉族   团员  大二            一般般                  较有特点
# 1    615.0   贾娜    黎族   团员  大四            完全是                  毫无特点
# 2    612.0   贾娜    汉族   党员  大三            可以算                 非常有特点
# 3    602.0  庞丽梅  维吾尔族   党员  大三            一般般                  较有特点
# 4    317.0  马英琦   蒙古族   团员  大二            可以算                  较无特点
# ..     ...  ...   ...  ...  ..            ...                   ...
# 774   16.0  黄明军    壮族   团员  大二            完全是                  较有特点
# 775   15.0  黄明军    汉族   团员  大二            完全是                 非常有特点
# 776    8.0  黄明军    满族   党员  大三            完全是                 非常有特点
# 777    7.0  黄明军    水族   团员  大二            完全是                 非常有特点
# 778    4.0  黄明军    苗族   团员  大二            完全是                 非常有特点
#
#     为公民，最基本的要求是爱自己的国家 不管是汉族还是少数民族，都是中华民族的一员 您是否为为中华民族的历史文化而骄傲  ... 会隐瞒身份吗  \
# 0               完全不同意                 完全不同意               不同意  ...   绝对不会
# ...

# %%
#逻辑一致性清理
数据表.您觉得自己是个典型的中国人吗.value_counts()
# Out:
# 您觉得自己是个典型的中国人吗
# 完全是     358
# 可以算     230
# 一般般     122
# 不太算      49
# 完全不是     20
# Name: count, dtype: int64

# %%
数据表.中国传统文化.value_counts()
# Out:
# 中国传统文化
# 富有内涵，意义深刻    551
# 比较肯定         207
# 古板，跟不上潮流      21
# Name: count, dtype: int64
